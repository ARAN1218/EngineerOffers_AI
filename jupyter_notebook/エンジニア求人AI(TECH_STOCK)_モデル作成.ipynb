# %% [markdown]
# <a href="https://colab.research.google.com/github/ARAN1218/EngineerOffers_AI/blob/main/jupyter_notebook/%E3%82%A8%E3%83%B3%E3%82%B8%E3%83%8B%E3%82%A2%E6%B1%82%E4%BA%BAAI(TECH_STOCK)_%E3%83%A2%E3%83%87%E3%83%AB%E4%BD%9C%E6%88%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run ./Engineer_Agent_functions.ipynb
import_test()
# Out:
# All Functions Imported!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
pd.set_option('display.max_columns', 600)
pd.set_option('display.max_rows', 600)
import scipy.stats as stats
import scikit_posthocs as sp
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import xgboost as xgb
import lightgbm as lgb
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %% [markdown]
# ## データ前処理

# %%
# データ読み込み
df = pd.read_pickle('Engineer_Agent_Bigdata.pickle')
df_pre = df.copy()
df.head(10)

# %%
# データ前処理
engineer_agent_preprocessing(df)
df.head(10)

# %% [markdown]
# ## データ分析

# %%
# 自作のdescribe関数をインポート
# %run ../descriptive_statistics_functions/describe2.ipynb

# %%
describe2(df['月額報酬'], df['勤務期間'])
# Out:
# 0       62.5
# 1       85.0
# 2       67.5
# 3       92.5
# 4       80.0
# 5       70.0
# 6       72.5
# 7       87.5
# 8       87.5
# 9       67.5
# 10      60.0
# 11      75.0
# 12      85.0
# 13      70.0
# 14     110.0
# 15      72.5
# 16      95.0
# 17      77.5
# 18      70.0
# 19      65.0
# 20     107.5
# 21      82.5
# 22      67.5
# 23      75.0
# 24      75.0
# 25      67.5
# 26      60.0
# 27      60.0
# 28      67.5
# 29      75.0
# 30      92.5
# 31      60.0
# 32      67.5
# 33      77.5
# 34      67.5
# 35      75.0
# 36      65.0
# 37      65.0
# 38      70.5
# 39     102.5
# 40      57.5
# 41      59.5
# 42      60.0
# 43      65.0
# 44      57.5
# 45      62.5
# 46      55.0
# 47      85.0
# 48      57.5
# 49      55.0
# 50      70.0
# 51      60.0
# 52     130.0
# 53      62.5
# 54      62.5
# 55      60.0
# 56      49.0
# 57      52.5
# 58      62.5
# 59      75.0
# 60      90.0
# 61     105.0
# 62     105.0
# 63     105.0
# 64     120.0
# 65     105.0
# ...

# %%
# データ分析は初手散布図や！
for column in list(df.columns):
    plt.scatter(df[column], df['月額報酬'])
    plt.title(column + " vs. 月額報酬")
    plt.xlabel(column)
    plt.ylabel("月額報酬")
    plt.show()

# %%
np.mean(df['月額報酬'][df["サーバエンジニア"] == 1])
# Out:
# 72.16176470588235

# %%
# 気になったデータを個別に見ていく
df_pre.query("index == 102")
# Out:
#      ページ                                               タイトル  \
# 102  603  \n【SAP】SAP S/4HANA Financeの海外拠点展開支援(メンバークラス) /...
#
#                   月額報酬                           勤務地  \
# 102  \n144～160万円(税別)\n  \n            リモート
#
#                               勤務期間                           稼働率  \
# 102  \n            即日～長期            \n            100%
#
#                                                   業務内容  \
# 102  \n            ・SAP/S4 HANA Finance(旧セントラルファイナン...
#
#                                                    スキル  \
# 102  \n          【必須スキル】\n            ・SAP FI導入経験　　...
#
#                               業種                            リモート  \
# 102  \n            製造業            \n            フルリモート
#
#                                                   募集職種  \
# 102  \n            SAPシステムコンサル / コンサル・PM・PMO
#
#                                             ポジション 募集人数 勤務時間   服装  \
# 102  \n            サブリーダー / メンバー / リーダー            NaN  NaN  NaN
#
# ...

# %%
# 気になった2群に対して、統計的検定をかけてみる
# 検定の多重性のため、近年では正規性を判断→ウェルチorマン=ホイットニーが主流らしいが、復習のために実装した
def is_normal(df1):
    return stats.shapiro(df1)[1] <= 0.05 # Trueで正規性なし

def is_equalval(df1, df2):
    return stats.bartlett(df1, df2)[1] > 0.05 # Trueで分散が異なる

def auto_test_2(df1, df2):
    if is_normal(df1)==False or is_normal(df2)==False:
        if is_equalval(df1, df2):
            print("正規性あり/等分散のため、スチューデントのt検定を使用")
            p = stats.ttest_ind(df1, df2, equal_var=True)[1]
            print("p値が{}のため、有意水準5%で2群間に差がある{}".format(p, 'と言える' if p<=0.05 else 'とは言えない'))
        else:
            print("正規性あり/非等分散のため、ウェルチのt検定を使用")
            p = stats.ttest_ind(df1, df2, equal_var=False)[1]
            print("p値が{}のため、有意水準5%で2群間に差がある{}".format(p, 'と言える' if p<=0.05 else 'とは言えない'))
    else:
        print("正規性なしのため、マン=ホイットニーのU検定を使用")
        p = stats.mannwhitneyu(df1, df2, alternative='two-sided')[1]
        print("p値が{}のため、有意水準5%で2群間に差がある{}".format(p, 'と言える' if p<=0.05 else 'とは言えない'))


auto_test_2(df['月額報酬'][df["サーバエンジニア"] == 1], df['月額報酬'][df['データサイエンティスト'] == 1])
# Out:
# 正規性あり/等分散のため、スチューデントのt検定を使用
# p値が0.05748268724379385のため、有意水準5%で2群間に差があるとは言えない

# %%
# 気になった3群に対して、多重比較をかけてみる
def multi_test(dfs):
    df_test = pd.DataFrame()
    for i, df in enumerate(dfs):
        d = pd.DataFrame({'value':df}).reset_index(drop=True)
        d['class'] = i+1
        df_test = pd.concat([df_test, d])
    #df1 = pd.DataFrame({'value':df1}).reset_index(drop=True)
    #df2 = pd.DataFrame({'value':df2}).reset_index(drop=True)
    #df3 = pd.DataFrame({'value':df3}).reset_index(drop=True)
    #df1['class'], df2['class'], df3['class'] = 1, 2, 3
    
    #df_test = pd.concat([df1, df2, df3])
    #display(df_test)
    
    # Steel-Dwass検定で統一
    display(sp.posthoc_dscf(df_test, val_col="value", group_col="class"))
    
multi_test([df['月額報酬'][df["契約形態"] == 0], df['月額報酬'][df["契約形態"] == 1], df['月額報酬'][df["契約形態"] == 2]])
# Out:
#           1         2         3
# 1  1.000000  0.209591  0.021354
# 2  0.209591  1.000000  0.358826
# 3  0.021354  0.358826  1.000000

# %% [markdown]
# #### 統計的検定の結果
# ①ポジション
# リーダー vs. メンバー
# →正規性なしのため、マン=ホイットニーのU検定を使用
# p値が4.451308737225001e-21のため、有意水準5%で2群間に差があると言える
#
# ポジションがリーダー vs. ポジションがメンバー
# →正規性あり/非等分散のため、ウェルチのt検定を使用
# p値が0.0009546517773851572のため、有意水準5%で2群間に差があると言える
#
# ②延長
# 延長あり vs. 延長なし
# →正規性なしのため、マン=ホイットニーのU検定を使用
# p値が0.0720812829446963のため、有意水準5%で2群間に差があるとは言えない
#
# ③服装
# →三群間に有意差はみられなかった。
#
# ④契約形態
# →業務委託と契約社員間に有意水準5%で有意差がみられた。

# %% [markdown]
# ## モデル作成(重回帰分析)

# %%
# データを学習用とテスト用に分割する
from sklearn.model_selection import train_test_split

df_x = df.drop(['月額報酬'], axis=1)
df_y = df['月額報酬']

df_l_x, df_t_x, df_l_y, df_t_y = train_test_split(df_x, df_y, shuffle=True, test_size=0.2, random_state=71)
display(df_l_x.head(10))
display(df_l_y.head(10))

# %%
# とりあえず重回帰分析からでしょ
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

model_lr = LinearRegression()
model_lr.fit(df_l_x, df_l_y)

df_pred = pd.DataFrame(model_lr.predict(df_t_x), columns=['pred']).reset_index(drop=True)
df_true = pd.DataFrame(df_t_y).reset_index(drop=True).set_axis(['true'], axis=1)

print('MAE:', mean_absolute_error(df_pred, df_true))
print('RMSE', np.sqrt(mean_squared_error(df_pred, df_true)))
display(pd.concat([df_pred, df_true], axis=1))
# Out:
# MAE: 14.960315751949356
# RMSE 18.982409044814325
#            pred   true
# 0     72.650966   67.5
# 1     62.591117   95.0
# 2    101.114044   72.5
# 3     70.593499   75.0
# 4    107.719152   90.0
# 5     83.542120   95.0
# 6     56.149681   72.5
# 7     67.341726   72.5
# 8    100.390687   90.0
# 9     62.565246   87.5
# 10   117.189136   67.5
# 11    67.647454   47.5
# 12    78.145149   70.0
# 13    53.667490   65.0
# 14    39.024561   50.0
# 15    68.295147   55.0
# 16    70.258961   85.0
# 17   108.694043  105.0
# 18    76.751375   75.0
# 19    78.890292   77.5
# 20   120.968868  125.0
# 21    64.360026   43.0
# 22   119.242666  135.0
# 23   110.166027  140.0
# 24    60.818403   62.5
# 25    91.165141  110.0
# 26   114.088619   80.0
# 27    72.593268   80.0
# 28    97.345278  150.0
# 29    76.832845   70.0
# 30    62.052155   60.0
# 31    76.555349   65.0
# 32    77.731816   87.5
# 33    60.522269   85.0
# 34    70.889631   62.5
# 35    68.492140   70.0
# ...

# %%
# 残差プロットを書いてみる
import matplotlib.pyplot as plt
plt.scatter(df_pred.pred, df_pred.pred - df_true.true, color = 'blue')
plt.hlines(y = 0, xmin = 20, xmax = 150, color = 'red')
plt.title('Residual Plot')
plt.xlabel('pred')
plt.ylabel('residuals')
plt.grid()
plt.show()

# %% [markdown]
# ## モデル作成(ランダムフォレスト)

# %%
# データを学習用とテスト用に分割する
from sklearn.model_selection import train_test_split

df_x = df.drop(['月額報酬'], axis=1)
df_y = df['月額報酬']

df_l_x, df_t_x, df_l_y, df_t_y = train_test_split(df_x, df_y, shuffle=True, test_size=0.2, random_state=71)
display(df_l_x.head(10))
display(df_l_y.head(10))

# %%
# 非線形を捉えるために決定木を試してみよう
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(max_depth=7)
model_rf.fit(df_l_x, df_l_y.astype(int))
df_pred = pd.DataFrame(model_rf.predict(df_t_x), columns=['pred']).reset_index(drop=True)
df_true = pd.DataFrame(df_t_y).reset_index(drop=True).set_axis(['true'], axis=1)

print('MAE:', mean_absolute_error(df_pred, df_true))
print('RMSE', np.sqrt(mean_squared_error(df_pred, df_true)))
display(pd.concat([df_pred, df_true], axis=1))
# Out:
# MAE: 14.645631067961165
# RMSE 23.43639398684866
#      pred   true
# 0      67   67.5
# 1      60   95.0
# 2      85   72.5
# 3      67   75.0
# 4     110   90.0
# 5      70   95.0
# 6      65   72.5
# 7      67   72.5
# 8      90   90.0
# 9      87   87.5
# 10    110   67.5
# 11     44   47.5
# 12     70   70.0
# 13     62   65.0
# 14     42   50.0
# 15     55   55.0
# 16     77   85.0
# 17    105  105.0
# 18     60   75.0
# 19     77   77.5
# 20    115  125.0
# 21     44   43.0
# 22    110  135.0
# 23    110  140.0
# 24     60   62.5
# 25    110  110.0
# 26    105   80.0
# 27     70   80.0
# 28    110  150.0
# 29     72   70.0
# 30     72   60.0
# 31     57   65.0
# 32     70   87.5
# 33     60   85.0
# 34     44   62.5
# 35     70   70.0
# 36    152   70.0
# 37    110   90.0
# 38     55   55.0
# 39     72   45.0
# 40    100  100.0
# 41    110  140.0
# 42     67   67.5
# 43     75   62.5
# 44     50   50.0
# 45    110  100.0
# 46     44   44.0
# 47     85   82.5
# ...

# %%
# 残差プロットを書いてみる
import matplotlib.pyplot as plt
plt.scatter(df_pred.pred, df_pred.pred - df_true.true, color = 'blue')
plt.hlines(y = 0, xmin = 20, xmax = 150, color = 'red')
plt.title('Residual Plot')
plt.xlabel('pred')
plt.ylabel('residuals')
plt.grid()
plt.show()

# %%
# 特徴量の重要度を見る
pd.DataFrame(model_rf.feature_importances_, index=df_x.columns, columns=['importance']).sort_values('importance', ascending=False)
# Out:
#                        importance
# 勤務地                      0.138578
# 業種                       0.102689
# 勤務期間                     0.083162
# リモート                     0.074798
# ポジション                    0.057516
# コンサル・PM・PMO              0.044295
# 稼働率                      0.039358
# 募集人数                     0.032833
# 延長                       0.032132
# 服装                       0.030758
# Java系エンジニア               0.029896
# システムエンジニア・プログラマー         0.029602
# インフラ・ネットワークエンジニア         0.029470
# SAP系(ABAP・BASIS)エンジニア    0.028854
# 契約形態                     0.026451
# バックエンドエンジニア              0.018327
# スマホアプリ開発                 0.015757
# フロントエンドエンジニア             0.014344
# Listening                0.013342
# 業務系エンジニア                 0.013093
# Speaking                 0.011935
# サーバエンジニア                 0.011907
# Writing                  0.011766
# その他オフィスワーク               0.011694
# カスタマーサポート                0.011381
# Reading                  0.011137
# ...

# %% [markdown]
# 重要度が高い順に
#
# 勤務地	0.137839
# 業種	0.096313
# 勤務期間	0.089779
# リモート	0.079012
# ポジション	0.054886
# コンサル・PM・PMO	0.046167
# 募集人数	0.045176
# 稼働率	0.036336
# 服装	0.032996
# 延長	0.032905
#
# であった。
# それ以外はほぼ詳細な業務名や英語の能力なので、この順番が主な影響力順と考えて差し支えなさそう。
# ただ、「契約形態」だけはあまり重要ではないらしい。
#
# また、英語の能力ではSpeakingが最も重要度が高く、職業名ではシステムエンジニア・プログラマーが最も影響していた。

# %% [markdown]
# ## XGBOOST

# %%
from sklearn.model_selection import train_test_split

df_x = df.drop(['月額報酬'], axis=1)
df_y = df['月額報酬']

# データを学習用とテスト用に分割する
tr_x, test_x, tr_y, test_y = train_test_split(df_x, df_y, shuffle=True, test_size=0.2, random_state=71)
# 学習用データを学習用と検証用に分割する
tr_x, va_x, tr_y, va_y = train_test_split(tr_x, tr_y, shuffle=True, test_size=0.2, random_state=71)
display(tr_x.head(10))
display(tr_y.head(10))

# %%
# xgboostモデルを組んでみる
import xgboost as xgb

#データ型をXGBOOST用に適合させる
dtrain = xgb.DMatrix(tr_x,label=tr_y)
dvalid = xgb.DMatrix(va_x,label=va_y)

#XGBOOSTのモデルを作成
num_round = 1000
early_stopping_rounds=50
params = {'objective':'reg:squarederror',
          'silent':1,
          'random_state':71
}
watchlist = [(dtrain,'train'),(dvalid,'eval')]
model_xgb = xgb.train(params,dtrain,num_round,early_stopping_rounds=early_stopping_rounds,evals=watchlist)

#テストデータとその予測結果を表示
test_pred = model_xgb.predict(xgb.DMatrix(test_x))
df_true = pd.DataFrame(list(test_y),columns=['月額報酬'])
df_pred = pd.DataFrame(test_pred,columns=['予測値'])
display(pd.concat([df_true,df_pred],axis=1))

#モデルの性能を表示
print('MAE:',mean_absolute_error(test_y,test_pred))
print('MSE:',mean_squared_error(test_y,test_pred))
print('RMSE:',np.sqrt(mean_squared_error(test_y,test_pred)))
# Out:
# [21:09:33] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:63.52092	eval-rmse:62.71790
# [1]	train-rmse:46.55328	eval-rmse:46.74023
# [2]	train-rmse:34.81801	eval-rmse:35.91293
# [3]	train-rmse:26.82266	eval-rmse:28.90161
# [4]	train-rmse:21.24732	eval-rmse:24.98357
# [5]	train-rmse:17.37189	eval-rmse:21.99396
# [6]	train-rmse:14.46518	eval-rmse:20.66737
# [7]	train-rmse:12.46554	eval-rmse:19.65119
# [8]	train-rmse:11.11145	eval-rmse:19.04786
# [9]	train-rmse:10.22440	eval-rmse:18.89994
# [10]	train-rmse:9.44528	eval-rmse:18.92447
# [11]	train-rmse:8.73785	eval-rmse:18.87184
# [12]	train-rmse:8.02676	eval-rmse:19.13324
# [13]	train-rmse:7.66113	eval-rmse:19.13029
# ...

# %% [markdown]
# 思ったより精度伸びなくてがっかりした...

# %% [markdown]
# ### アプリ化

# %% [markdown]
# office preprocessed!
#
# ['リモート' '三重県' '中之島または阿波座から徒歩5分' '中部地方、神戸市' '京王多摩センター駅' '京都府' '京都府京都市'
#  '全国可' '六本木駅' '兵庫県' '兵庫県明石市' '兵庫県神戸市' '北海道' '北海道札幌市' '北海道札幌市中央区' '北海道札幌市内'
#  '北海道札幌市内or東京都' '北海道札幌市北区' '千葉県' '名古屋市' '名古屋市上前津駅' '名古屋市上前津駅または三重県津駅'
#  '品川区' '四ツ谷駅' '地下鉄西新駅' '堺筋本町駅' '大崎駅' '大通駅' '大阪ビジネスパーク駅' '大阪付守口市'
#  '大阪市住之江区南港北' '大阪市内' '大阪府' '大阪府大東市' '大阪府大阪市' '大阪府茨木市' '大阪府豊中市' '天王駅' '尼崎市'
#  '府中駅' '志村坂上駅' '愛知県' '愛知県名古屋市' '愛知県名古屋市中区' '愛知県名古屋市南区' '摂津市' '明石市' '木場駅'
#  '札幌市' '札幌市中央区' '札幌市内' '札幌市北区' '東京神保町' '東京都' '東京都23区内' '東京都23区外'
#  '東京都、北海道札幌市内' '東京都、大阪府' '東京都世田谷区' '東京都中央区' '東京都中央区または港区' '東京都中野区' '東京都内'
#  '東京都千代田区' '東京都台東区' '東京都品川区' '東京都墨田区' '東京都多摩市' '東京都新宿区' '東京都江東区' '東京都渋谷区'
#  '東京都港区' '東京都豊島区' '東京都都内' '横浜札幌' '江東区' '淀屋橋駅または中之島駅' '港区' '田町' '確認中'
#  '神奈川県' '神奈川県横浜市' '神奈川県藤沢市' '神戸市' '神戸市内' '福岡市中央区' '福岡県北九州市' '福岡県福岡市'
#  '福島県いわき市' '縄福岡県福岡市' '群馬県' '虎ノ門ヒルズ駅分' '虎ノ門駅' '表参道駅' '西新宿駅' '豊田市三河豊田駅' '都内']
#
#
# type preprocessed!
#
# ['サービス業(他に分類されないもの)' '不動産業、物品賃貸業' '医療・福祉業' '卸売業' '学術研究、専門・技術サービス業' '官公庁'
#  '小売業' '建設業' '情報通信業' '教育・学習支援業' '生活関連サービス業、娯楽業' '製造業' '複合サービス事業' '農林水産業'
#  '運輸業、郵便業' '金融業、保険業' '電気・ガス・熱供給・水道業' '非公開']
#
# remote preprocessed!
#
# ['なし（常駐）' 'フルリモート' '月1回程度のクライアント訪問' '月2回程度のクライアント訪問' '週1回程度リモート'
#  '週2回程度リモート' '週3回程度リモート' '週4回程度リモート']

# %%
LE_office.transform(['都内'])

# %%
pred_data = pd.DataFrame({
    '勤務地':LE_office.transform(['確認中']),
    '勤務期間':12, # 1年間 = 12
    '稼働率':100, # パーセント
    '業種':LE_type.transform(['非公開']),
    'リモート':LE_remote.transform(['なし（常駐）']),
    'ポジション':0, # メンバー:0、サブリーダー:1、リーダー:2
    '募集人数':1, 
    '服装':1, # スーツネクタイ着用:0, ビジネスカジュアル:1, 私服可:2
    '契約形態':0, # 業務委託:0, 派遣:1, 契約社員:2
    '延長':0,
    
    # 職業名
    'その他オフィスワーク':0, 
    'システムエンジニア・プログラマー':0, 
    'インフラ・ネットワークエンジニア':0, 
    'ネットワークエンジニア':0,
    'コンサル・PM・PMO':0,
    'テスター・デバッカー':0, 
    'フロントエンドエンジニア':0,
    'バックエンドエンジニア':0,
    'デザイナー・クリエイター':0,
    'Java系エンジニア':0,
    '業務系エンジニア':0,
    'サーバエンジニア':0,
    '運用/監視担当':0,
    '企画・マーケティング':0,
    'データサイエンティスト':0,
    'DBA(データベース)管理者':0,
    'ヘルプデスク':0,
    'スマホアプリ開発':0,
    'ソーシャル系エンジニア':0,
    '制御・組み込み系エンジニア':0,
    'ゲームプログラマー/ゲームクリエイター':0,
    'アナリスト':0,
    'カスタマーサポート':0,
    'Webディレクター':0,
    'SAP系(ABAP・BASIS)エンジニア':0,
    'Windows系エンジニア':0,
    'LAMP系エンジニア':0,
    
    # 英語スキル
    'Reading':1,
    'Listening':1,
    'Speaking':0,
    'Writing':0
}, index=['pred'])
display(pred_data)

pred = model_xgb.predict(xgb.DMatrix(pred_data))
display(pd.DataFrame(pred,columns=['月額報酬']))
# Out:
#       勤務地  勤務期間  稼働率  業種  リモート  ポジション  募集人数  服装  契約形態  延長  その他オフィスワーク  \
# pred   79    12  100  17     0      0     1   1     0   0           0
#
#       システムエンジニア・プログラマー  インフラ・ネットワークエンジニア  ネットワークエンジニア  コンサル・PM・PMO  \
# pred                 0                 0            0            0
#
#       テスター・デバッカー  フロントエンドエンジニア  バックエンドエンジニア  デザイナー・クリエイター  Java系エンジニア  \
# pred           0             0            0             0           0
#
#       業務系エンジニア  サーバエンジニア  運用/監視担当  企画・マーケティング  データサイエンティスト  DBA(データベース)管理者  \
# pred         0         0        0           0            0               0
#
#       ヘルプデスク  スマホアプリ開発  ソーシャル系エンジニア  制御・組み込み系エンジニア  ゲームプログラマー/ゲームクリエイター  \
# pred       0         0            0              0                    0
#
#       アナリスト  カスタマーサポート  Webディレクター  SAP系(ABAP・BASIS)エンジニア  Windows系エンジニア  \
# pred      0          0          0                      0              0
#
#       LAMP系エンジニア  Reading  Listening  Speaking  Writing
# ...

# %%
print(LE_office)

# %%
df[df['ゲームプログラマー/ゲームクリエイター'] == 1]

# %%
df['月額報酬'][df['データサイエンティスト'] == 1].mean()

# %% [markdown]
# ## 大本命モデリング(Light GBM)

# %% [markdown]
# 質的変数をカテゴリカルデータとして有効活用できるので、これが正しいAIモデルである。

# %%
# データを学習用とテスト用に分割する
from sklearn.model_selection import train_test_split

df_x = df.drop(['月額報酬'], axis=1)
df_y = df['月額報酬']

# データを学習用とテスト用に分割する
tr_x, test_x, tr_y, test_y = train_test_split(df_x, df_y, shuffle=True, test_size=0.2, random_state=71)
# 学習用データを学習用と検証用に分割する
tr_x, va_x, tr_y, va_y = train_test_split(tr_x, tr_y, shuffle=True, test_size=0.2, random_state=71)
display(tr_x.head(10))
display(tr_y.head(10))

# %%
#必要なライブラリをインポート
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


# カテゴリ変数をそのまま使う
#データ型をLIGHTGBM用に適合させる。
ltrain = lgb.Dataset(tr_x,tr_y)
lvalid = lgb.Dataset(va_x,va_y,reference=ltrain)

#パラメータ準備
params = {'objective':'regression','metrics':'rmse','silent':1,'random_state':71,
          'max_depth':7,
          'min_child_weight':2,
          'gamma':0.2,
          'colsample_bytree':1.0,
          'colsample_bylevel':0.3,
          'subsample':0.07,
          'alpha':1,
          'eta':0.1, 
          #'lambda':1
         }
num_round = 1000
early_stopping_rounds = 50

#LIGHTGBMモデルに機械学習
categorical_feature = ['勤務地', '業種', 'リモート', 'ポジション', '服装', '契約形態']
model_lgb = lgb.train(params,ltrain,num_boost_round=num_round,
                  early_stopping_rounds=early_stopping_rounds,
                  valid_names=['train','valid'],valid_sets=[ltrain,lvalid],
                 categorical_feature=categorical_feature)
test_pred = model_lgb.predict(test_x)

#モデルの性能を表示させる。
print('MAE:',mean_absolute_error(test_y,test_pred))
print('MSE:',mean_squared_error(test_y,test_pred))
print('RMSE:',np.sqrt(mean_squared_error(test_y,test_pred)))

#テストデータとその予測結果を表示させる。
#見やすくする為に、concatで横に実値と予測値を結合させる。
#実値のindexがめちゃくちゃだったので、reset_indexメソッドでindexをリセットしてから結合させた。
test_y_df = pd.DataFrame(test_y).reset_index(drop=True)
test_pred_df = pd.DataFrame(test_pred,columns=['prediction'])
display(pd.concat([test_y_df,test_pred_df],axis=1))
# Out:
# [1]	train's rmse: 27.6246	valid's rmse: 26.8682
# Training until validation scores don't improve for 50 rounds.
# [2]	train's rmse: 26.5781	valid's rmse: 25.9144
# [3]	train's rmse: 25.698	valid's rmse: 25.1196
# [4]	train's rmse: 24.9361	valid's rmse: 24.3828
# [5]	train's rmse: 24.237	valid's rmse: 23.7014
# [6]	train's rmse: 23.6837	valid's rmse: 23.1102
# [7]	train's rmse: 23.2268	valid's rmse: 22.676
# [8]	train's rmse: 22.7918	valid's rmse: 22.2598
# [9]	train's rmse: 22.3335	valid's rmse: 21.8957
# [10]	train's rmse: 21.8728	valid's rmse: 21.5553
# [11]	train's rmse: 21.4924	valid's rmse: 21.2806
# [12]	train's rmse: 21.0481	valid's rmse: 20.7534
# [13]	train's rmse: 20.7701	valid's rmse: 20.5643
# [14]	train's rmse: 20.4332	valid's rmse: 20.1687
# [15]	train's rmse: 20.1575	valid's rmse: 19.8505
# [16]	train's rmse: 19.9268	valid's rmse: 19.7468
# [17]	train's rmse: 19.6863	valid's rmse: 19.509
# [18]	train's rmse: 19.4268	valid's rmse: 19.3718
# ...

# %% [markdown]
# ### アプリ化

# %% [markdown]
# office preprocessed!
#
# ['リモート' '三重県' '中之島または阿波座から徒歩5分' '中部地方、神戸市' '京王多摩センター駅' '京都府' '京都府京都市'
#  '全国可' '六本木駅' '兵庫県' '兵庫県明石市' '兵庫県神戸市' '北海道' '北海道札幌市' '北海道札幌市中央区' '北海道札幌市内'
#  '北海道札幌市内or東京都' '北海道札幌市北区' '千葉県' '名古屋市' '名古屋市上前津駅' '名古屋市上前津駅または三重県津駅'
#  '品川区' '四ツ谷駅' '地下鉄西新駅' '堺筋本町駅' '大崎駅' '大通駅' '大阪ビジネスパーク駅' '大阪付守口市'
#  '大阪市住之江区南港北' '大阪市内' '大阪府' '大阪府大東市' '大阪府大阪市' '大阪府茨木市' '大阪府豊中市' '天王駅' '尼崎市'
#  '府中駅' '志村坂上駅' '愛知県' '愛知県名古屋市' '愛知県名古屋市中区' '愛知県名古屋市南区' '摂津市' '明石市' '木場駅'
#  '札幌市' '札幌市中央区' '札幌市内' '札幌市北区' '東京神保町' '東京都' '東京都23区内' '東京都23区外'
#  '東京都、北海道札幌市内' '東京都、大阪府' '東京都世田谷区' '東京都中央区' '東京都中央区または港区' '東京都中野区' '東京都内'
#  '東京都千代田区' '東京都台東区' '東京都品川区' '東京都墨田区' '東京都多摩市' '東京都新宿区' '東京都江東区' '東京都渋谷区'
#  '東京都港区' '東京都豊島区' '東京都都内' '横浜札幌' '江東区' '淀屋橋駅または中之島駅' '港区' '田町' '確認中'
#  '神奈川県' '神奈川県横浜市' '神奈川県藤沢市' '神戸市' '神戸市内' '福岡市中央区' '福岡県北九州市' '福岡県福岡市'
#  '福島県いわき市' '縄福岡県福岡市' '群馬県' '虎ノ門ヒルズ駅分' '虎ノ門駅' '表参道駅' '西新宿駅' '豊田市三河豊田駅' '都内']
#
#
# type preprocessed!
#
# ['サービス業(他に分類されないもの)' '不動産業、物品賃貸業' '医療・福祉業' '卸売業' '学術研究、専門・技術サービス業' '官公庁'
#  '小売業' '建設業' '情報通信業' '教育・学習支援業' '生活関連サービス業、娯楽業' '製造業' '複合サービス事業' '農林水産業'
#  '運輸業、郵便業' '金融業、保険業' '電気・ガス・熱供給・水道業' '非公開']
#
# remote preprocessed!
#
# ['なし（常駐）' 'フルリモート' '月1回程度のクライアント訪問' '月2回程度のクライアント訪問' '週1回程度リモート'
#  '週2回程度リモート' '週3回程度リモート' '週4回程度リモート']

# %%
pred_data = pd.DataFrame({
    '勤務地':LE_office.transform(['確認中']),
    '勤務期間':12, # 1年間 = 12
    '稼働率':100, # パーセント
    '業種':LE_type.transform(['非公開']),
    'リモート':LE_remote.transform(['なし（常駐）']),
    'ポジション':0, # メンバー:0、サブリーダー:1、リーダー:2
    '募集人数':1,
    '服装':0, # スーツネクタイ着用:0, ビジネスカジュアル:1, 私服可:2
    '契約形態':0, # 業務委託:0, 派遣:1, 契約社員:2
    '延長':0,
    
    # 職業名
    'その他オフィスワーク':0,
    'システムエンジニア・プログラマー':0, 
    'インフラ・ネットワークエンジニア':0, 
    'ネットワークエンジニア':0,
    'コンサル・PM・PMO':0,
    'テスター・デバッカー':0, 
    'フロントエンドエンジニア':0,
    'バックエンドエンジニア':0,
    'デザイナー・クリエイター':0,
    'Java系エンジニア':0,
    '業務系エンジニア':0,
    'サーバエンジニア':0,
    '運用/監視担当':0,
    '企画・マーケティング':0,
    'データサイエンティスト':1,
    'DBA(データベース)管理者':0,
    'ヘルプデスク':0,
    'スマホアプリ開発':0,
    'ソーシャル系エンジニア':0,
    '制御・組み込み系エンジニア':0,
    'ゲームプログラマー/ゲームクリエイター':0,
    'アナリスト':0,
    'カスタマーサポート':0,
    'Webディレクター':0,
    'SAP系(ABAP・BASIS)エンジニア':0,
    'Windows系エンジニア':0,
    'LAMP系エンジニア':0,
    
    # 英語スキル
    'Reading':1,
    'Listening':1,
    'Speaking':0,
    'Writing':0
}, index=['pred'])
display(pred_data)

pred = model_lgb.predict(pred_data)
display(pd.DataFrame(pred,columns=['月額報酬'],index=['予測値(万円)']))
# Out:
#       勤務地  勤務期間  稼働率  業種  リモート  ポジション  募集人数  服装  契約形態  延長  その他オフィスワーク  \
# pred   79    12  100  17     0      0     1   0     0   1           0
#
#       システムエンジニア・プログラマー  インフラ・ネットワークエンジニア  ネットワークエンジニア  コンサル・PM・PMO  \
# pred                 0                 0            0            0
#
#       テスター・デバッカー  フロントエンドエンジニア  バックエンドエンジニア  デザイナー・クリエイター  Java系エンジニア  \
# pred           0             0            0             0           0
#
#       業務系エンジニア  サーバエンジニア  運用/監視担当  企画・マーケティング  データサイエンティスト  DBA(データベース)管理者  \
# pred         0         0        0           0            1               0
#
#       ヘルプデスク  スマホアプリ開発  ソーシャル系エンジニア  制御・組み込み系エンジニア  ゲームプログラマー/ゲームクリエイター  \
# pred       0         0            0              0                    0
#
#       アナリスト  カスタマーサポート  Webディレクター  SAP系(ABAP・BASIS)エンジニア  Windows系エンジニア  \
# pred      0          0          0                      0              0
#
#       LAMP系エンジニア  Reading  Listening  Speaking  Writing
# ...
